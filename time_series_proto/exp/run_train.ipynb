# %%
import pdb

# %%
from google.colab import drive
mount = '/content/gdrive'
drive.mount(mount)
drive_root = mount + "/My Drive/DPSN-modified/DPSN-modified/time_series_proto/"
# %cd $drive_root
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/DPSN-modified/DPSN-modified/time_series_proto

# %%
# pdb.set_trace()
# !bash scripts/train_proto.sh 0 2 linear_transform ./exp/train.py
# Out:
# 0.1 0 already done result =  0.8241666666666667
# 0.1 1 already done result =  0.82625
# 0.1 2 already done result =  0.85125
# 0.1 3 already done result =  0.8108333333333333
# 0.1 4 already done result =  0.8729166666666667
# 0.1 5 already done result =  0.8254166666666667
# 0.1 6 already done result =  0.8433333333333333
# 0.1 7 already done result =  0.80125
# 0.1 8 already done result =  0.84875
# 0.1 9 already done result =  0.8525
# 0.2 0 already done result =  0.8795833333333333
# 0.2 1 already done result =  0.87
# 0.2 2 already done result =  0.8679166666666667
# 0.2 3 already done result =  0.845
# 0.2 4 already done result =  0.85125
# 0.2 5 already done result =  0.8808333333333332
# 0.2 6 already done result =  0.8670833333333333
# 0.2 7 already done result =  0.8654166666666667
# 0.2 8 already done result =  0.8816666666666667
# 0.2 9 already done result =  0.8429166666666668
# 0.3 0 already done result =  0.8904166666666667
# 0.3 1 already done result =  0.8729166666666667
# 0.3 2 already done result =  0.8745833333333333
# 0.3 3 already done result =  0.7983333333333333
# 0.3 4 already done result =  0.8870833333333333
# 0.3 5 already done result =  0.8691666666666668
# 0.3 6 already done result =  0.8620833333333333
# 0.3 7 already done result =  0.8241666666666667
# 0.3 8 already done result =  0.8683333333333333
# 0.3 9 already done result =  0.8758333333333332
# 0.4 0 already done result =  0.87375
# 0.4 1 already done result =  0.84625
# 0.4 2 already done result =  0.8316666666666667
# 0.4 3 already done result =  0.8883333333333333
# 0.4 4 already done result =  0.8983333333333333
# 0.4 5 already done result =  0.87875
# 0.4 6 already done result =  0.85625
# 0.4 7 already done result =  0.8766666666666667
# 0.4 8 already done result =  0.85875
# 0.4 9 already done result =  0.8620833333333333
# 0.5 0 already done result =  0.8491666666666667
# 0.5 1 already done result =  0.8725
# 0.5 2 already done result =  0.8845833333333333
# 0.5 3 already done result =  0.8866666666666667
# 0.5 4 already done result =  0.8816666666666667
# 0.5 5 already done result =  0.84375
# 0.5 6 already done result =  0.85
# 0.5 7 already done result =  0.8504166666666667
# 0.5 8 already done result =  0.8758333333333332
# 0.5 9 already done result =  0.9225
# 0.6 0 already done result =  0.8954166666666667
# 0.6 1 already done result =  0.8383333333333333
# 0.6 2 already done result =  0.89
# 0.6 3 already done result =  0.8883333333333333
# 0.6 4 already done result =  0.8833333333333333
# 0.6 5 already done result =  0.9283333333333332
# 0.6 6 already done result =  0.8625
# 0.6 7 already done result =  0.8645833333333333
# 0.6 8 already done result =  0.8829166666666667
# 0.6 9 already done result =  0.8783333333333333
# 0.7 0 already done result =  0.88625
# 0.7 1 already done result =  0.8791666666666668
# 0.7 2 already done result =  0.8770833333333333
# 0.7 3 already done result =  0.885
# 0.7 4 already done result =  0.875
# 0.7 5 already done result =  0.8733333333333333
# 0.7 6 already done result =  0.88
# 0.7 7 already done result =  0.9008333333333333
# 0.7 8 already done result =  0.9129166666666667
# 0.7 9 already done result =  0.8816666666666667
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.8
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.8
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.8
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.8
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.8
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.8
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.8
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.8
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.8
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.8
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.9
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.9
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.9
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.9
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.9
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.9
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.9
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.9
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.9
# args :
# Namespace(dataset_root='../SFA_Python-master/test/WM_feature_Data_pyts/', iterations=100, img_up_bound=None, epochs=1000, workers=8, manual_seed=6661, arch='linear_transform', log_dir='./logs/5shot_linear_transform/', log_interval=20, test_interval=10, lr=0.002, lr_step=10000, lr_gamma=0.7, momentum=0.9, weight_decay=1e-05, batch_size=512, classes_per_it_tr=None, num_support_tr=2, num_query_tr=2, classes_per_it_val=None, num_support_val=2, num_query_val=2, name_list=None)
# 0.9

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/DPSN-modified/DPSN-modified/time_series_proto
